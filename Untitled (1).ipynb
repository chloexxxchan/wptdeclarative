# %%
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#import images
import urllib.request
import PIL
urllib.request.urlretrieve("https://i.imgur.com/gy9Osvn.jpg", "file-a1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/NyW7Y6c.jpg", "file-b1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/8BhuieM.jpg", "file-c1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/wBPCx5Q.jpg", "file-d1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/8vx9YpB.jpg", "file-e1.jpg")

#urllib.request.urlretrieve("https://i.imgur.com/ZyMdi1u.jpg", "file-f1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/iFGOo8l.jpg", "file-g1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/8GDIIIn.jpg", "file-h1.jpg")

#urllib.request.urlretrieve("https://i.imgur.com/vuj6NnK.jpg", "file-i1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/MEkPxOe.jpg", "file-j1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/ibenwgd.jpg", "file-k1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/M4m8SCr.jpg", "file-l1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/XoGnG3n.jpg", "file-n1.jpg")

urllib.request.urlretrieve("https://i.imgur.com/DRTL0nR.jpg", "file-m1.jpg")



#wpt no 1
greeting1 = input("Welcome to the weather prediction task! Press enter: ")
print("What’s happening in this task: ")
print("- you will be displayed a cue which is an image that has one to three")
print("cards on it with black shapes on them which can be either squares, ")
print("circles, triangles, or diamonds")
print("- You will also be shown either a sun or rain next to this “cue” which")
print("will be the type of weather that is associated with the cue")
print("example cue:") 
img = mpimg.imread('file-c1.jpg')
imgplot = plt.imshow(img)
plt.show()
print("your job is to try to memorize these cues.")
print("\n")
input("Press enter to begin the task.")
img = mpimg.imread('file-a1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5) 
#wptt part 2
img = mpimg.imread('file-d1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wpt task part 3
img = mpimg.imread('file-e1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wpt no 4
img = mpimg.imread('file-g1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wptt part 5
img = mpimg.imread('file-j1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wpt task part 6
img = mpimg.imread('file-m1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wpt no 7
img = mpimg.imread('file-a1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)

#wptt part 8
img = mpimg.imread('file-c1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)
#wpt task part 9
img = mpimg.imread('file-h1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)

#wpt no 10
img = mpimg.imread('file-k1.jpg')
imgplot = plt.imshow(img)
plt.show()
time.sleep(5)

print("yay! you are done with this part of the task")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     806         try:
# --> 807             msg_list = socket.recv_multipart(mode, copy=copy)
#     808         except zmq.ZMQError as e:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
import builtins
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
denom = 0;
num = 0;
#import images
import urllib.request
import PIL
urllib.request.urlretrieve("https://i.imgur.com/LVkodJF.jpg", "file-a.jpg")
urllib.request.urlretrieve("https://i.imgur.com/vvuZTvD.jpg", "file-b.jpg")
urllib.request.urlretrieve("https://i.imgur.com/uFC9leR.jpg", "file-c.jpg")
urllib.request.urlretrieve("https://i.imgur.com/Dgyuajq.jpg", "file-d.jpg")
urllib.request.urlretrieve("https://i.imgur.com/U2RaZNU.jpg", "file-e.jpg")
#urllib.request.urlretrieve("https://i.imgur.com/H1IsBh8.jpg", "file-f.jpg")
urllib.request.urlretrieve("https://i.imgur.com/gLd7MJC.jpg", "file-g.jpg")
urllib.request.urlretrieve("https://i.imgur.com/EuIhBIg.jpg", "file-h.jpg")
#urllib.request.urlretrieve("https://i.imgur.com/5GAN77h.jpg", "file-i.jpg")
urllib.request.urlretrieve("https://i.imgur.com/DaAMxL9.jpg", "file-j.jpg")
urllib.request.urlretrieve("https://i.imgur.com/1GTZlSY.jpg", "file-k.jpg")
urllib.request.urlretrieve("https://i.imgur.com/amjQdnN.jpg", "file-l.jpg")
urllib.request.urlretrieve("https://i.imgur.com/3MyGJYD.jpg", "file-m.jpg")
urllib.request.urlretrieve("https://i.imgur.com/jVCvbo5.jpg", "file-n.jpg")
#wpt no 1
denom = denom + 1
greeting1 = input("Welcome to the weather prediction task! Press enter: ")
print("// insert directions here //")
input("Press enter to begin.")
img = mpimg.imread('file-b.jpg')
imgplot = plt.imshow(img)
plt.show()
from threading import Thread
a1nswer = None
def checktime():
  time.sleep(3) 
  if a1nswer == None:
      print("2 seconds left") 
Thread(target = checktime).start()
start = time.time()
a1nswer = builtins.input("enter f or j here: ")
end = time.time()
d1uration = end-start
if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration < 5:
    if a1nswer == "f" or a1nswer == "F":
      num = num + 1
else:
      print("oops you didn't make it in time")
#wptt part 2
denom = denom + 1
input("Press enter to begin.")
img = mpimg.imread('file-c.jpg')
imgplot = plt.imshow(img)
plt.show()
 
from threading import Thread
a1nswer1 = None
def checktime():
  time.sleep(3) 
  if a1nswer1 == None:
      print("2 seconds left")     
Thread(target = checktime).start()
 
start = time.time()
a1nswer1 = input("enter f or j here: ")
end = time.time()
d1uration1 = end-start
if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration1 < 5:
    if a1nswer1 == "f" or a1nswer1 == "F":
      num = num + 1
else:
      print("oops you didn't make it in time")
#wpt task part 3
denom = denom + 1
input("Press enter to continue.")
img = mpimg.imread('file-n.jpg')
imgplot = plt.imshow(img)
plt.show()

from threading import Thread
a1nswer2 = None
def checktime():
  time.sleep(3) 
  if a1nswer2 == None:
      print("2 seconds left")   
Thread(target = checktime).start()
 
start = time.time()
a1nswer2 = input("enter f or j here: ")
end = time.time()
d1uration2 = end-start
if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration2 < 5:
    if a1nswer2 == "j" or a1nswer2 == "J":
      num = num + 1
else:
      print("oops you didn't make it in time")
#wpt no 4
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-g.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer3 = None

def checktime():
  time.sleep(3) 
  if a1nswer3 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer3 = input("enter f or j here: ")
end = time.time()
d1uration3 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration3 < 5:
    if a1nswer3 == "f" or a1nswer3 == "F":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wptt part 5
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-j.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer4 = None

def checktime():
  time.sleep(3) 
  if a1nswer4 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer4 = input("enter f or j here: ")
end = time.time()
d1uration4 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration4 < 5:
    if a1nswer4 == "j" or a1nswer4 == "J":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wpt task part 6
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-k.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer5 = None

def checktime():
  time.sleep(3) 
  if a1nswer5 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer5 = input("enter f or j here: ")
end = time.time()
d1uration5 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration5 < 5:
    if a1nswer5 == "f" or a1nswer5 == "F":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wpt no 7
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-l.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer6 = None

def checktime():
  time.sleep(3) 
  if a1nswer6 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer6 = input("enter f or j here: ")
end = time.time()
d1uration6 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration6 < 5:
    if a1nswer6 == "j" or a1nswer6 == "J":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wptt part 8
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-m.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer7 = None

def checktime():
  time.sleep(3) 
  if a1nswer7 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer7 = input("enter f or j here: ")
end = time.time()
d1uration7 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration7 < 5:
    if a1nswer7 == "j" or a1nswer7 == "J":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wpt task part 9
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-h.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer8 = None

def checktime():
  time.sleep(3) 
  if a1nswer8 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer8 = input("enter f or j here: ")
end = time.time()
d1uration8 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration8 < 5:
    if a1nswer8 == "j" or a1nswer8 == "J":
      num = num + 1
else:
      print("oops you didn't make it in time")

#wpt no 10
denom = denom + 1
input("Press enter to continue.")

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('file-e.jpg')
imgplot = plt.imshow(img)
plt.show()
 

from threading import Thread

a1nswer9 = None

def checktime():
  time.sleep(3) 
  if a1nswer9 == None:
      print("2 seconds left")
      
Thread(target = checktime).start()


start = time.time()

a1nswer9 = input("enter f or j here: ")
end = time.time()
d1uration9 = end-start

if start != None and end != None: 
  print("took you", (end-start), "seconds")
if d1uration9 < 5:
    if a1nswer9 == "f" or a1nswer9 == "F":
      num = num + 1
else:
      print("oops you didn't make it in time")
print("percent correct" + str((100*num)/denom))
print("yay! you have completed this part of the task")
